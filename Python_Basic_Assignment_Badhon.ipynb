# %% [markdown]
# <a href="https://colab.research.google.com/github/BadhonPain/AI_ML/blob/Basic_Python/Python_Basic_Assignment_Badhon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write a Python program that prints the following text exactly:
# Welcome to Python Programming!
# I am learning the basics.
print("Welcome to Python Programming!\nI am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %%
# Create two variables:
# - name → your name
# - age → your age

# Print the output like this:
# My name is Tahmid and I am 25 years old.
name = "Badhon"
age = str(20)
print("My name is "+name+" and I am "+age+" years old.")
# Out:
# My name is Badhon and I am 20 years old.

# %%
# Take user input for:
# - Name
# - Favorite programming language
# Print a message:
# Hello <name>, your favorite language is <language>.
name = input()
fav_lang = input()
print("Hello "+name+", your favorite language is "+fav_lang)
# Out:
# Badhon
# Java
# Hello Badhon, your favorite language is Java

# %%
# 1. Take two numbers from the user using input()
# 2. Convert them to integers
# 3. Print their sum
# Example output:
# The sum is: 30
num1 = int(input())
num2 = int(input())
print("The sum is: "+str(num1+num2))
# Out:
# 10
# 20
# The sum is: 30

# %%
# Take two numbers from the user and:
# - Convert them to integers
# - Print Addition
# - Print Subtraction
# - Print Multiplication

# Example:
# Addition: 20
# Subtraction: 10
# Multiplication: 75
num1 = int(input())
num2 = int(input())
print("Addition: "+str(num1+num2))
print("Subtraction: "+str(num1-num2))
print("Multiplication: "+str(num1*num2))
# Out:
# 30
# 12
# Addition: 42
# Subtraction: 18
# Multiplication: 360
